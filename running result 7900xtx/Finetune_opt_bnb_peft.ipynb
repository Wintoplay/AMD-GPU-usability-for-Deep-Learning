# %% [markdown]
# ## Fine-tune large models using 🤗 `peft` adapters, `transformers` & `bitsandbytes`
#
# In this tutorial we will cover how we can fine-tune large language models using the very recent `peft` library and `bitsandbytes` for loading large models in 8-bit.
# The fine-tuning method will rely on a recent method called "Low Rank Adapters" (LoRA), instead of fine-tuning the entire model you just have to fine-tune these adapters and load them properly inside the model.
# After fine-tuning the model you can also share your adapters on the 🤗 Hub and load them very easily. Let's get started!

# %% [markdown]
# ### Install requirements
#
# First, run the cells below to install the requirements:

# %%
# %pip install -q bitsandbytes datasets accelerate loralib
# %pip install -q git+https://github.com/huggingface/transformers.git@main git+https://github.com/huggingface/peft.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 79.3 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done

# %% [markdown]
# ### Model loading
#
# Here let's load the `opt-6.7b` model, its weights in half-precision (float16) are about 13GB on the Hub! If we load them in 8-bit we would require around 7GB of memory instead.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import torch
import torch.nn as nn
import bitsandbytes as bnb
from transformers import AutoTokenizer, AutoConfig, AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "facebook/opt-6.7b",
    torch_dtype = torch.bfloat16,
    device_map='auto',
)

tokenizer = AutoTokenizer.from_pretrained("facebook/opt-6.7b")
# Out:
# /home/win/torch2/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /home/win/torch2/lib/python3.10/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /home/win/torch2/lib/python3.10/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Post-processing on the model
#
# Finally, we need to apply some post-processing on the 8-bit model to enable training, let's freeze all our layers, and cast the layer-norm in `float32` for stability. We also cast the output of the last layer in `float32` for the same reasons.

# %%
for param in model.parameters():
  param.requires_grad = False  # freeze the model - train adapters later
  if param.ndim == 1:
    # cast the small parameters (e.g. layernorm) to fp32 for stability
    param.data = param.data.to(torch.float32)

model.gradient_checkpointing_enable()  # reduce number of stored activations
model.enable_input_require_grads()

class CastOutputToFloat(nn.Sequential):
  def forward(self, x): return super().forward(x).to(torch.float32)
model.lm_head = CastOutputToFloat(model.lm_head)

# %% [markdown]
# ### Apply LoRA
#
# Here comes the magic with `peft`! Let's load a `PeftModel` and specify that we are going to use low-rank adapters (LoRA) using `get_peft_model` utility function from `peft`.

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
print_trainable_parameters(model)
# Out:
# trainable params: 8388608 || all params: 6666862592 || trainable%: 0.12582542214183376

# %% [markdown]
# ### Training

# %%
import transformers
from datasets import load_dataset
data = load_dataset("Abirate/english_quotes")
data = data.map(lambda samples: tokenizer(samples['quote']), batched=True)

trainer = transformers.Trainer(
    model=model,
    train_dataset=data['train'],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=100,
        max_steps=250,
        learning_rate=2e-4,
        bf16=True,
        fp16=False,
        logging_steps=1,
        output_dir='outputs'
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /home/win/torch2/lib/python3.10/site-packages/torch/utils/checkpoint.py:461: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 2.2958, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.01}
# {'loss': 2.2365, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.01}
# {'loss': 1.7998, 'learning_rate': 6e-06, 'epoch': 0.02}
# {'loss': 2.4948, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.03}
# {'loss': 2.5741, 'learning_rate': 1e-05, 'epoch': 0.03}
# {'loss': 2.3022, 'learning_rate': 1.2e-05, 'epoch': 0.04}
# {'loss': 2.3775, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.04}
# {'loss': 2.5061, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.05}
# {'loss': 2.3588, 'learning_rate': 1.8e-05, 'epoch': 0.06}
# {'loss': 1.7815, 'learning_rate': 2e-05, 'epoch': 0.06}
# {'loss': 2.1735, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.07}
# {'loss': 2.6158, 'learning_rate': 2.4e-05, 'epoch': 0.08}
# {'loss': 2.2044, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.08}
# {'loss': 2.1286, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.09}
# {'loss': 2.5501, 'learning_rate': 3e-05, 'epoch': 0.1}
# {'loss': 2.5426, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.1}
# {'loss': 2.3432, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.11}
# {'loss': 2.374, 'learning_rate': 3.6e-05, 'epoch': 0.11}
# {'loss': 1.9248, 'learning_rate': 3.8e-05, 'epoch': 0.12}
# {'loss': 1.6596, 'learning_rate': 4e-05, 'epoch': 0.13}
# {'loss': 1.7969, 'learning_rate': 4.2e-05, 'epoch': 0.13}
# {'loss': 2.4637, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.14}
# {'loss': 2.0288, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.15}
# {'loss': 2.3357, 'learning_rate': 4.8e-05, 'epoch': 0.15}
# {'loss': 2.0949, 'learning_rate': 5e-05, 'epoch': 0.16}
# {'loss': 1.8078, 'learning_rate': 5.2000000000000004e-05, 'epoch': 0.17}
# {'loss': 1.7543, 'learning_rate': 5.4000000000000005e-05, 'epoch': 0.17}
# {'loss': 1.685, 'learning_rate': 5.6000000000000006e-05, 'epoch': 0.18}
# {'loss': 2.2303, 'learning_rate': 5.8e-05, 'epoch': 0.19}
# {'loss': 1.8778, 'learning_rate': 6e-05, 'epoch': 0.19}
# {'loss': 1.9955, 'learning_rate': 6.2e-05, 'epoch': 0.2}
# {'loss': 2.1719, 'learning_rate': 6.400000000000001e-05, 'epoch': 0.2}
# {'loss': 1.8655, 'learning_rate': 6.6e-05, 'epoch': 0.21}
# {'loss': 2.4177, 'learning_rate': 6.800000000000001e-05, 'epoch': 0.22}
# {'loss': 1.996, 'learning_rate': 7e-05, 'epoch': 0.22}
# {'loss': 1.9714, 'learning_rate': 7.2e-05, 'epoch': 0.23}
# {'loss': 2.1132, 'learning_rate': 7.4e-05, 'epoch': 0.24}
# {'loss': 2.1127, 'learning_rate': 7.6e-05, 'epoch': 0.24}
# {'loss': 1.8516, 'learning_rate': 7.800000000000001e-05, 'epoch': 0.25}
# {'loss': 1.9944, 'learning_rate': 8e-05, 'epoch': 0.26}
# {'loss': 1.5101, 'learning_rate': 8.2e-05, 'epoch': 0.26}
# {'loss': 2.0093, 'learning_rate': 8.4e-05, 'epoch': 0.27}
# {'loss': 2.5084, 'learning_rate': 8.6e-05, 'epoch': 0.27}
# {'loss': 1.8222, 'learning_rate': 8.800000000000001e-05, 'epoch': 0.28}
# {'loss': 1.769, 'learning_rate': 9e-05, 'epoch': 0.29}
# {'loss': 1.5354, 'learning_rate': 9.200000000000001e-05, 'epoch': 0.29}
# {'loss': 1.9369, 'learning_rate': 9.4e-05, 'epoch': 0.3}
# {'loss': 2.0383, 'learning_rate': 9.6e-05, 'epoch': 0.31}
# {'loss': 1.8429, 'learning_rate': 9.8e-05, 'epoch': 0.31}
# {'loss': 1.7319, 'learning_rate': 0.0001, 'epoch': 0.32}
# {'loss': 2.1918, 'learning_rate': 0.00010200000000000001, 'epoch': 0.33}
# {'loss': 1.8499, 'learning_rate': 0.00010400000000000001, 'epoch': 0.33}
# {'loss': 1.7802, 'learning_rate': 0.00010600000000000002, 'epoch': 0.34}
# {'loss': 1.9796, 'learning_rate': 0.00010800000000000001, 'epoch': 0.34}
# {'loss': 1.8894, 'learning_rate': 0.00011000000000000002, 'epoch': 0.35}
# {'loss': 1.9147, 'learning_rate': 0.00011200000000000001, 'epoch': 0.36}
# {'loss': 1.971, 'learning_rate': 0.00011399999999999999, 'epoch': 0.36}
# {'loss': 2.1067, 'learning_rate': 0.000116, 'epoch': 0.37}
# {'loss': 1.9956, 'learning_rate': 0.000118, 'epoch': 0.38}
# {'loss': 1.8586, 'learning_rate': 0.00012, 'epoch': 0.38}
# {'loss': 2.1599, 'learning_rate': 0.000122, 'epoch': 0.39}
# {'loss': 1.6104, 'learning_rate': 0.000124, 'epoch': 0.4}
# {'loss': 2.2641, 'learning_rate': 0.000126, 'epoch': 0.4}
# {'loss': 1.4967, 'learning_rate': 0.00012800000000000002, 'epoch': 0.41}
# {'loss': 1.466, 'learning_rate': 0.00013000000000000002, 'epoch': 0.41}
# {'loss': 1.4716, 'learning_rate': 0.000132, 'epoch': 0.42}
# {'loss': 1.7811, 'learning_rate': 0.000134, 'epoch': 0.43}
# {'loss': 1.8831, 'learning_rate': 0.00013600000000000003, 'epoch': 0.43}
# {'loss': 1.677, 'learning_rate': 0.000138, 'epoch': 0.44}
# {'loss': 1.9858, 'learning_rate': 0.00014, 'epoch': 0.45}
# {'loss': 2.0913, 'learning_rate': 0.000142, 'epoch': 0.45}
# {'loss': 2.0364, 'learning_rate': 0.000144, 'epoch': 0.46}
# {'loss': 1.5788, 'learning_rate': 0.000146, 'epoch': 0.47}
# {'loss': 1.5554, 'learning_rate': 0.000148, 'epoch': 0.47}
# {'loss': 2.2113, 'learning_rate': 0.00015000000000000001, 'epoch': 0.48}
# {'loss': 1.9512, 'learning_rate': 0.000152, 'epoch': 0.48}
# {'loss': 1.5189, 'learning_rate': 0.000154, 'epoch': 0.49}
# {'loss': 1.6966, 'learning_rate': 0.00015600000000000002, 'epoch': 0.5}
# {'loss': 2.2415, 'learning_rate': 0.00015800000000000002, 'epoch': 0.5}
# {'loss': 1.7995, 'learning_rate': 0.00016, 'epoch': 0.51}
# {'loss': 2.2192, 'learning_rate': 0.000162, 'epoch': 0.52}
# {'loss': 1.8235, 'learning_rate': 0.000164, 'epoch': 0.52}
# {'loss': 1.9977, 'learning_rate': 0.000166, 'epoch': 0.53}
# {'loss': 2.2115, 'learning_rate': 0.000168, 'epoch': 0.54}
# {'loss': 1.2825, 'learning_rate': 0.00017, 'epoch': 0.54}
# {'loss': 1.9432, 'learning_rate': 0.000172, 'epoch': 0.55}
# {'loss': 1.988, 'learning_rate': 0.000174, 'epoch': 0.56}
# {'loss': 1.8725, 'learning_rate': 0.00017600000000000002, 'epoch': 0.56}
# {'loss': 1.3992, 'learning_rate': 0.00017800000000000002, 'epoch': 0.57}
# {'loss': 1.9627, 'learning_rate': 0.00018, 'epoch': 0.57}
# {'loss': 1.93, 'learning_rate': 0.000182, 'epoch': 0.58}
# {'loss': 1.7427, 'learning_rate': 0.00018400000000000003, 'epoch': 0.59}
# {'loss': 1.5207, 'learning_rate': 0.00018600000000000002, 'epoch': 0.59}
# {'loss': 1.5946, 'learning_rate': 0.000188, 'epoch': 0.6}
# {'loss': 1.7118, 'learning_rate': 0.00019, 'epoch': 0.61}
# {'loss': 1.9787, 'learning_rate': 0.000192, 'epoch': 0.61}
# {'loss': 1.8942, 'learning_rate': 0.000194, 'epoch': 0.62}
# {'loss': 1.7885, 'learning_rate': 0.000196, 'epoch': 0.63}
# {'loss': 1.5417, 'learning_rate': 0.00019800000000000002, 'epoch': 0.63}
# {'loss': 1.8967, 'learning_rate': 0.0002, 'epoch': 0.64}
# {'loss': 1.7788, 'learning_rate': 0.00019866666666666668, 'epoch': 0.64}
# {'loss': 1.7544, 'learning_rate': 0.00019733333333333335, 'epoch': 0.65}
# {'loss': 2.1967, 'learning_rate': 0.000196, 'epoch': 0.66}
# {'loss': 1.9234, 'learning_rate': 0.0001946666666666667, 'epoch': 0.66}
# {'loss': 1.8643, 'learning_rate': 0.00019333333333333333, 'epoch': 0.67}
# {'loss': 1.8781, 'learning_rate': 0.000192, 'epoch': 0.68}
# {'loss': 2.0325, 'learning_rate': 0.00019066666666666668, 'epoch': 0.68}
# {'loss': 2.3135, 'learning_rate': 0.00018933333333333335, 'epoch': 0.69}
# {'loss': 2.0293, 'learning_rate': 0.000188, 'epoch': 0.7}
# {'loss': 2.0841, 'learning_rate': 0.0001866666666666667, 'epoch': 0.7}
# {'loss': 1.8227, 'learning_rate': 0.00018533333333333333, 'epoch': 0.71}
# {'loss': 2.0862, 'learning_rate': 0.00018400000000000003, 'epoch': 0.71}
# {'loss': 2.1764, 'learning_rate': 0.00018266666666666667, 'epoch': 0.72}
# {'loss': 1.8359, 'learning_rate': 0.00018133333333333334, 'epoch': 0.73}
# {'loss': 1.6111, 'learning_rate': 0.00018, 'epoch': 0.73}
# {'loss': 1.5764, 'learning_rate': 0.00017866666666666668, 'epoch': 0.74}
# {'loss': 2.1218, 'learning_rate': 0.00017733333333333335, 'epoch': 0.75}
# {'loss': 1.4032, 'learning_rate': 0.00017600000000000002, 'epoch': 0.75}
# {'loss': 1.5474, 'learning_rate': 0.00017466666666666667, 'epoch': 0.76}
# {'loss': 1.9538, 'learning_rate': 0.00017333333333333334, 'epoch': 0.77}
# {'loss': 1.5233, 'learning_rate': 0.000172, 'epoch': 0.77}
# {'loss': 1.616, 'learning_rate': 0.00017066666666666668, 'epoch': 0.78}
# {'loss': 1.769, 'learning_rate': 0.00016933333333333335, 'epoch': 0.78}
# {'loss': 1.7165, 'learning_rate': 0.000168, 'epoch': 0.79}
# {'loss': 2.0224, 'learning_rate': 0.0001666666666666667, 'epoch': 0.8}
# {'loss': 1.6487, 'learning_rate': 0.00016533333333333333, 'epoch': 0.8}
# {'loss': 1.7091, 'learning_rate': 0.000164, 'epoch': 0.81}
# {'loss': 2.0544, 'learning_rate': 0.00016266666666666667, 'epoch': 0.82}
# {'loss': 1.9807, 'learning_rate': 0.00016133333333333334, 'epoch': 0.82}
# {'loss': 1.9915, 'learning_rate': 0.00016, 'epoch': 0.83}
# {'loss': 1.9451, 'learning_rate': 0.00015866666666666668, 'epoch': 0.84}
# {'loss': 1.7951, 'learning_rate': 0.00015733333333333333, 'epoch': 0.84}
# {'loss': 1.967, 'learning_rate': 0.00015600000000000002, 'epoch': 0.85}
# {'loss': 2.0935, 'learning_rate': 0.00015466666666666667, 'epoch': 0.85}
# {'loss': 2.3721, 'learning_rate': 0.00015333333333333334, 'epoch': 0.86}
# {'loss': 1.8874, 'learning_rate': 0.000152, 'epoch': 0.87}
# {'loss': 2.1568, 'learning_rate': 0.00015066666666666668, 'epoch': 0.87}
# {'loss': 2.2528, 'learning_rate': 0.00014933333333333335, 'epoch': 0.88}
# {'loss': 1.7153, 'learning_rate': 0.000148, 'epoch': 0.89}
# {'loss': 2.0567, 'learning_rate': 0.00014666666666666666, 'epoch': 0.89}
# {'loss': 2.3262, 'learning_rate': 0.00014533333333333333, 'epoch': 0.9}
# {'loss': 1.915, 'learning_rate': 0.000144, 'epoch': 0.91}
# {'loss': 1.6564, 'learning_rate': 0.00014266666666666667, 'epoch': 0.91}
# {'loss': 1.9183, 'learning_rate': 0.00014133333333333334, 'epoch': 0.92}
# {'loss': 1.9593, 'learning_rate': 0.00014, 'epoch': 0.93}
# {'loss': 1.7087, 'learning_rate': 0.00013866666666666669, 'epoch': 0.93}
# {'loss': 1.7891, 'learning_rate': 0.00013733333333333333, 'epoch': 0.94}
# {'loss': 2.3564, 'learning_rate': 0.00013600000000000003, 'epoch': 0.94}
# {'loss': 1.4972, 'learning_rate': 0.00013466666666666667, 'epoch': 0.95}
# {'loss': 2.1089, 'learning_rate': 0.00013333333333333334, 'epoch': 0.96}
# {'loss': 1.9695, 'learning_rate': 0.000132, 'epoch': 0.96}
# {'loss': 1.4218, 'learning_rate': 0.00013066666666666668, 'epoch': 0.97}
# {'loss': 1.9964, 'learning_rate': 0.00012933333333333332, 'epoch': 0.98}
# {'loss': 2.1675, 'learning_rate': 0.00012800000000000002, 'epoch': 0.98}
# {'loss': 1.9, 'learning_rate': 0.00012666666666666666, 'epoch': 0.99}
# {'loss': 1.9622, 'learning_rate': 0.00012533333333333334, 'epoch': 1.0}
# {'loss': 1.5285, 'learning_rate': 0.000124, 'epoch': 1.0}
# {'loss': 1.7434, 'learning_rate': 0.00012266666666666668, 'epoch': 1.01}
# {'loss': 1.9548, 'learning_rate': 0.00012133333333333335, 'epoch': 1.01}
# {'loss': 1.847, 'learning_rate': 0.00012, 'epoch': 1.02}
# {'loss': 1.811, 'learning_rate': 0.00011866666666666669, 'epoch': 1.03}
# {'loss': 2.0602, 'learning_rate': 0.00011733333333333334, 'epoch': 1.03}
# {'loss': 1.7177, 'learning_rate': 0.000116, 'epoch': 1.04}
# {'loss': 1.7817, 'learning_rate': 0.00011466666666666667, 'epoch': 1.05}
# {'loss': 1.9602, 'learning_rate': 0.00011333333333333334, 'epoch': 1.05}
# {'loss': 1.7292, 'learning_rate': 0.00011200000000000001, 'epoch': 1.06}
# {'loss': 1.5885, 'learning_rate': 0.00011066666666666667, 'epoch': 1.07}
# {'loss': 1.8778, 'learning_rate': 0.00010933333333333333, 'epoch': 1.07}
# {'loss': 1.8735, 'learning_rate': 0.00010800000000000001, 'epoch': 1.08}
# {'loss': 1.9346, 'learning_rate': 0.00010666666666666667, 'epoch': 1.08}
# {'loss': 1.8961, 'learning_rate': 0.00010533333333333332, 'epoch': 1.09}
# {'loss': 1.967, 'learning_rate': 0.00010400000000000001, 'epoch': 1.1}
# {'loss': 1.9174, 'learning_rate': 0.00010266666666666666, 'epoch': 1.1}
# {'loss': 1.7885, 'learning_rate': 0.00010133333333333335, 'epoch': 1.11}
# {'loss': 2.2889, 'learning_rate': 0.0001, 'epoch': 1.12}
# {'loss': 1.6199, 'learning_rate': 9.866666666666668e-05, 'epoch': 1.12}
# {'loss': 2.0292, 'learning_rate': 9.733333333333335e-05, 'epoch': 1.13}
# {'loss': 1.9174, 'learning_rate': 9.6e-05, 'epoch': 1.14}
# {'loss': 1.6377, 'learning_rate': 9.466666666666667e-05, 'epoch': 1.14}
# {'loss': 1.6752, 'learning_rate': 9.333333333333334e-05, 'epoch': 1.15}
# {'loss': 1.8597, 'learning_rate': 9.200000000000001e-05, 'epoch': 1.15}
# {'loss': 1.4996, 'learning_rate': 9.066666666666667e-05, 'epoch': 1.16}
# {'loss': 2.1739, 'learning_rate': 8.933333333333334e-05, 'epoch': 1.17}
# {'loss': 1.8874, 'learning_rate': 8.800000000000001e-05, 'epoch': 1.17}
# {'loss': 1.5472, 'learning_rate': 8.666666666666667e-05, 'epoch': 1.18}
# {'loss': 1.5064, 'learning_rate': 8.533333333333334e-05, 'epoch': 1.19}
# {'loss': 1.9969, 'learning_rate': 8.4e-05, 'epoch': 1.19}
# {'loss': 1.3296, 'learning_rate': 8.266666666666667e-05, 'epoch': 1.2}
# {'loss': 1.7729, 'learning_rate': 8.133333333333334e-05, 'epoch': 1.21}
# {'loss': 2.0522, 'learning_rate': 8e-05, 'epoch': 1.21}
# {'loss': 1.7757, 'learning_rate': 7.866666666666666e-05, 'epoch': 1.22}
# {'loss': 2.0215, 'learning_rate': 7.733333333333333e-05, 'epoch': 1.22}
# {'loss': 1.6926, 'learning_rate': 7.6e-05, 'epoch': 1.23}
# {'loss': 1.9411, 'learning_rate': 7.466666666666667e-05, 'epoch': 1.24}
# {'loss': 1.9331, 'learning_rate': 7.333333333333333e-05, 'epoch': 1.24}
# {'loss': 1.6528, 'learning_rate': 7.2e-05, 'epoch': 1.25}
# {'loss': 2.1245, 'learning_rate': 7.066666666666667e-05, 'epoch': 1.26}
# {'loss': 2.0734, 'learning_rate': 6.933333333333334e-05, 'epoch': 1.26}
# {'loss': 1.5349, 'learning_rate': 6.800000000000001e-05, 'epoch': 1.27}
# {'loss': 1.9387, 'learning_rate': 6.666666666666667e-05, 'epoch': 1.28}
# {'loss': 1.7857, 'learning_rate': 6.533333333333334e-05, 'epoch': 1.28}
# {'loss': 1.6073, 'learning_rate': 6.400000000000001e-05, 'epoch': 1.29}
# {'loss': 1.7305, 'learning_rate': 6.266666666666667e-05, 'epoch': 1.3}
# {'loss': 1.8107, 'learning_rate': 6.133333333333334e-05, 'epoch': 1.3}
# {'loss': 2.0541, 'learning_rate': 6e-05, 'epoch': 1.31}
# {'loss': 1.9765, 'learning_rate': 5.866666666666667e-05, 'epoch': 1.31}
# {'loss': 2.2728, 'learning_rate': 5.7333333333333336e-05, 'epoch': 1.32}
# {'loss': 1.3728, 'learning_rate': 5.6000000000000006e-05, 'epoch': 1.33}
# {'loss': 1.7592, 'learning_rate': 5.466666666666666e-05, 'epoch': 1.33}
# {'loss': 1.6521, 'learning_rate': 5.333333333333333e-05, 'epoch': 1.34}
# {'loss': 2.1108, 'learning_rate': 5.2000000000000004e-05, 'epoch': 1.35}
# {'loss': 1.6462, 'learning_rate': 5.0666666666666674e-05, 'epoch': 1.35}
# {'loss': 1.9552, 'learning_rate': 4.933333333333334e-05, 'epoch': 1.36}
# {'loss': 1.6819, 'learning_rate': 4.8e-05, 'epoch': 1.37}
# {'loss': 1.7992, 'learning_rate': 4.666666666666667e-05, 'epoch': 1.37}
# {'loss': 2.3644, 'learning_rate': 4.5333333333333335e-05, 'epoch': 1.38}
# {'loss': 2.0312, 'learning_rate': 4.4000000000000006e-05, 'epoch': 1.38}
# {'loss': 1.82, 'learning_rate': 4.266666666666667e-05, 'epoch': 1.39}
# {'loss': 1.9019, 'learning_rate': 4.133333333333333e-05, 'epoch': 1.4}
# {'loss': 2.0235, 'learning_rate': 4e-05, 'epoch': 1.4}
# {'loss': 1.6594, 'learning_rate': 3.866666666666667e-05, 'epoch': 1.41}
# {'loss': 2.3641, 'learning_rate': 3.733333333333334e-05, 'epoch': 1.42}
# {'loss': 2.0212, 'learning_rate': 3.6e-05, 'epoch': 1.42}
# {'loss': 1.6312, 'learning_rate': 3.466666666666667e-05, 'epoch': 1.43}
# {'loss': 2.433, 'learning_rate': 3.3333333333333335e-05, 'epoch': 1.44}
# {'loss': 1.979, 'learning_rate': 3.2000000000000005e-05, 'epoch': 1.44}
# {'loss': 2.1367, 'learning_rate': 3.066666666666667e-05, 'epoch': 1.45}
# {'loss': 1.9548, 'learning_rate': 2.9333333333333336e-05, 'epoch': 1.45}
# {'loss': 1.809, 'learning_rate': 2.8000000000000003e-05, 'epoch': 1.46}
# {'loss': 1.3824, 'learning_rate': 2.6666666666666667e-05, 'epoch': 1.47}
# {'loss': 2.1618, 'learning_rate': 2.5333333333333337e-05, 'epoch': 1.47}
# {'loss': 1.433, 'learning_rate': 2.4e-05, 'epoch': 1.48}
# {'loss': 1.6138, 'learning_rate': 2.2666666666666668e-05, 'epoch': 1.49}
# {'loss': 1.638, 'learning_rate': 2.1333333333333335e-05, 'epoch': 1.49}
# {'loss': 2.0531, 'learning_rate': 2e-05, 'epoch': 1.5}
# {'loss': 2.1761, 'learning_rate': 1.866666666666667e-05, 'epoch': 1.51}
# {'loss': 1.9875, 'learning_rate': 1.7333333333333336e-05, 'epoch': 1.51}
# {'loss': 1.51, 'learning_rate': 1.6000000000000003e-05, 'epoch': 1.52}
# {'loss': 2.1084, 'learning_rate': 1.4666666666666668e-05, 'epoch': 1.52}
# {'loss': 1.6668, 'learning_rate': 1.3333333333333333e-05, 'epoch': 1.53}
# {'loss': 1.5993, 'learning_rate': 1.2e-05, 'epoch': 1.54}
# {'loss': 2.0121, 'learning_rate': 1.0666666666666667e-05, 'epoch': 1.54}
# {'loss': 2.2246, 'learning_rate': 9.333333333333334e-06, 'epoch': 1.55}
# {'loss': 1.6871, 'learning_rate': 8.000000000000001e-06, 'epoch': 1.56}
# {'loss': 2.1958, 'learning_rate': 6.666666666666667e-06, 'epoch': 1.56}
# {'loss': 1.2189, 'learning_rate': 5.333333333333334e-06, 'epoch': 1.57}
# {'loss': 1.8451, 'learning_rate': 4.000000000000001e-06, 'epoch': 1.58}
# {'loss': 1.8293, 'learning_rate': 2.666666666666667e-06, 'epoch': 1.58}
# {'loss': 1.8953, 'learning_rate': 1.3333333333333334e-06, 'epoch': 1.59}
# {'loss': 1.9807, 'learning_rate': 0.0, 'epoch': 1.59}
# {'train_runtime': 341.7468, 'train_samples_per_second': 11.705, 'train_steps_per_second': 0.732, 'train_loss': 1.911065619468689, 'epoch': 1.59}
# TrainOutput(global_step=250, training_loss=1.911065619468689, metrics={'train_runtime': 341.7468, 'train_samples_per_second': 11.705, 'train_steps_per_second': 0.732, 'train_loss': 1.911065619468689, 'epoch': 1.59})

# %% [markdown]
# RTX7900 xtx
# 200 steps: 04:33
# 250 steps: 341.7468

# %%
batch = tokenizer("Two things are infinite: ", return_tensors='pt').to('cuda')

with torch.cuda.amp.autocast():
    model = model
    output_tokens = model.generate(**batch, max_new_tokens=50)

print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
# /home/win/torch2/lib/python3.10/site-packages/torch/utils/checkpoint.py:461: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /home/win/torch2/lib/python3.10/site-packages/torch/utils/checkpoint.py:91: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  Two things are infinite:  the universe and human stupidity; and I'm not sure about the former.  - Albert Einstein
# I'm not sure about the universe either.

# %%
# !pip show bitsandbytes
# Out:
# Name: bitsandbytes
# Version: 0.39.0
# Summary: 8-bit optimizers and matrix multiplication routines.
# Home-page: https://github.com/st1vms/bitsandbytes-rocm-gfx1100
# Author: Tim Dettmers
# Author-email: dettmers@cs.washington.edu
# License: MIT
# Location: /home/win/torch2/lib/python3.10/site-packages/bitsandbytes-0.39.0-py3.10.egg
# Requires:
# Required-by:

# %% [markdown]
# ## Share adapters on the 🤗 Hub

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("Winmodel/opt-6.7b-lora", use_auth_token=True)
# Out:
# /home/win/torch2/lib/python3.10/site-packages/transformers/utils/hub.py:821: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# adapter_model.safetensors:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Winmodel/opt-6.7b-lora/commit/83e8a386811814157c1959194fc9ee6a6d4b6d8e', commit_message='Upload model', commit_description='', oid='83e8a386811814157c1959194fc9ee6a6d4b6d8e', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Save model locally

# %%
model.save_pretrained("/mnt/1df6b45e-20dc-41ca-9a04-b271fd3a4940/Learn/Fintuned models")

# %% [markdown]
# ## Load adapters from the Hub
#
# You can also directly load adapters from the Hub using the commands below:

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_id = "ybelkada/opt-6.7b-lora"
config = PeftConfig.from_pretrained(peft_model_id)
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_8bit=True, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 112
# CUDA SETUP: Loading binary /usr/local/lib/python3.8/dist-packages/bitsandbytes/libbitsandbytes_cuda112.so...
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/share/tcltk/tcllib1.19')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-38j9a9wfgbvb0 --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('6000,"kernelManagerProxyHost"'), PosixPath('true}'), PosixPath('["--ip=172.28.0.12","--transport=ipc"],"debugAdapterMultiplexerPath"'), PosixPath('"172.28.0.12","jupyterArgs"'), PosixPath('"/usr/local/bin/dap_multiplexer","enableLsp"'), PosixPath('{"kernelManagerProxyPort"')}
#   warn(msg)
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/cuda_setup/main.py:134: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(msg)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)"adapter_model.bin";:   0%|          | 0.00/33.6M [00:00<?, ?B/s]

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_dir = "/mnt/1df6b45e-20dc-41ca-9a04-b271fd3a4940/Learn/Fintuned models/opt-6.7"
config = PeftConfig.from_pretrained(peft_model_dir)
model = AutoModelForCausalLM.from_pretrained(
    "facebook/opt-6.7b",
    torch_dtype = torch.bfloat16,
    device_map='auto',
)

tokenizer = AutoTokenizer.from_pretrained("facebook/opt-6.7b")

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
batch = tokenizer("Two things are infinite: ", return_tensors='pt').to("cuda")

with torch.cuda.amp.autocast():
  output_tokens = model.generate(**batch, max_new_tokens=50)

print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
#  Two things are infinite:  the universe and human stupidity; and I'm not sure about the universe.  -Albert Einstein
# I'm not sure about the universe either.

# %% [markdown]
# ## Inference
#
# You can then directly use the trained model or the model that you have loaded from the 🤗 Hub for inference as you would do it usually in `transformers`.

# %%
batch = tokenizer("Two things are infinite: ", return_tensors='pt')

with torch.cuda.amp.autocast():
  output_tokens = model.generate(**batch, max_new_tokens=50)

print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:1359: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/bitsandbytes/autograd/_functions.py:233: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  Two things are infinite:  the universe and human stupidity; and I'm not sure about the universe.  -Albert Einstein
# I'm not sure about the universe either.

# %% [markdown]
# As you can see by fine-tuning for few steps we have almost recovered the quote from Albert Einstein that is present in the [training data](https://huggingface.co/datasets/Abirate/english_quotes).
